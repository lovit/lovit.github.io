# %%
import numpy as np

n_data_per_class = 50
n_classes = 3

x = []
y = []
for c in range(n_classes):
    x_ = 0.3 * np.random.random_sample((n_data_per_class, 2))
    x_ += np.random.random_sample((1, 2))
    x.append(x_)
    y.append(np.asarray([c] * n_data_per_class))
x = np.vstack(x)
y = np.concatenate(y)

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.layouts import gridplot
from bokeh.io import export_png

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b066d273-754a-4ecc-a59c-4606261a6656">Loading BokehJS ...</span>
#     </div>

# %%
title = '{} classes {} points'.format(n_classes, n_classes * n_data_per_class)

def draw_figure(x, y, title, show_figure=True,
    colors = 'firebrick darksalmon lightseagreen'.split()):

    p = figure(width=400, height=400, title=title)
    for c in range(n_classes):
        idx = np.where(y == c)[0]
        x_ = x[idx]
        p.scatter(x_[:,0], x_[:,1], fill_color=colors[c], line_color=colors[c])
    if show_figure:
        show(p)
    return p

p = draw_figure(x, y, title)
export_png(p, '../assets/figures/embedding_for_vis_lle_various_k_data.png')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="120751d3-ca8b-4e69-8e77-499368e18c83"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("120751d3-ca8b-4e69-8e77-499368e18c83");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("120751d3-ca8b-4e69-8e77-499368e18c83");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '120751d3-ca8b-4e69-8e77-499368e18c83' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3d004040-1575-4847-bb86-95ac553f89bb":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"08b1a3a0-dadc-4219-b8f8-0b8b55bd50b4","type":"BoxAnnotation"},{"attributes":{"source":{"id":"6d874916-6fe2-460b-ba1e-1b477fd7969b","type":"ColumnDataSource"}},"id":"602894e4-a734-4586-b5ba-48da2a40bf07","type":"CDSView"},{"attributes":{},"id":"6a314a76-f201-43f2-91cf-7a146ac5f638","type":"BasicTicker"},{"attributes":{},"id":"87eaaaea-6320-45c1-acc8-60cc08de429d","type":"PanTool"},{"attributes":{"source":{"id":"be077829-109a-44e2-aec6-82e7a06e72c0","type":"ColumnDataSource"}},"id":"810fe91b-963c-4853-be25-3ad1ae479e48","type":"CDSView"},{"attributes":{"fill_color":{"value":"darksalmon"},"line_color":{"value":"darksalmon"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f94a2e69-520e-4526-8f92-f0a71f16abd4","type":"Circle"},{"attributes":{"plot":{"id":"51032169-13fb-47b6-9f96-13fac83facb3","subtype":"Figure","type":"Plot"},"ticker":{"id":"a7de1a7c-28ec-4687-a53f-7fd8cad6cdab","type":"BasicTicker"}},"id":"c34523da-0163-44da-bd84-9ee84d6942ad","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"51032169-13fb-47b6-9f96-13fac83facb3","subtype":"Figure","type":"Plot"},"ticker":{"id":"6a314a76-f201-43f2-91cf-7a146ac5f638","type":"BasicTicker"}},"id":"d62b168a-a108-44cd-952c-f52243967b13","type":"Grid"},{"attributes":{"data_source":{"id":"6d874916-6fe2-460b-ba1e-1b477fd7969b","type":"ColumnDataSource"},"glyph":{"id":"f94a2e69-520e-4526-8f92-f0a71f16abd4","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c95059ca-8652-4c20-9a01-47cf879eb6a6","type":"Circle"},"selection_glyph":null,"view":{"id":"602894e4-a734-4586-b5ba-48da2a40bf07","type":"CDSView"}},"id":"12f0c236-bc39-4a03-a005-90f3054cc8af","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"d0fe632d-d19a-4cb1-b50e-4ba3d1ddf719","type":"ColumnDataSource"},"glyph":{"id":"23e8bc61-47cc-46d4-a30b-ea8fb5a81090","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1937e6fd-da6b-4022-a8ca-2ede522d3a14","type":"Circle"},"selection_glyph":null,"view":{"id":"5b1c12e0-0482-4b28-848a-5e7528d30031","type":"CDSView"}},"id":"9708c384-def1-49b5-aacd-9b6131eea38f","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"72e7f1ce-5ecd-441f-88d9-e5d918d67a22","type":"BasicTickFormatter"},"plot":{"id":"51032169-13fb-47b6-9f96-13fac83facb3","subtype":"Figure","type":"Plot"},"ticker":{"id":"a7de1a7c-28ec-4687-a53f-7fd8cad6cdab","type":"BasicTicker"}},"id":"0a9aec5f-4a11-4a41-b1ed-32dc056b1539","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"firebrick"},"line_color":{"value":"firebrick"},"x":{"field":"x"},"y":{"field":"y"}},"id":"23e8bc61-47cc-46d4-a30b-ea8fb5a81090","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[50]},"y":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"d0fe632d-d19a-4cb1-b50e-4ba3d1ddf719","type":"ColumnDataSource"},{"attributes":{},"id":"44db333a-21e3-4bdd-b287-d2852c9931b9","type":"BasicTickFormatter"},{"attributes":{},"id":"85768383-51ce-450c-90ba-a4854377cee3","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[50]},"y":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"6d874916-6fe2-460b-ba1e-1b477fd7969b","type":"ColumnDataSource"},{"attributes":{},"id":"72e7f1ce-5ecd-441f-88d9-e5d918d67a22","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c95059ca ...
# /home/lovit/anaconda2/envs/scrapper/lib/python3.6/site-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# WARNING:bokeh.io:The webdriver raised a TimeoutException while waiting for                      a 'bokeh:idle' event to signify that the layout has rendered.                      Something may have gone wrong.
# '/mnt/lovit/git/lovit.github.io/assets/figures/embedding_for_vis_lle_various_k_data.png'

# %%
from sklearn.manifold import LocallyLinearEmbedding

plots = []
for n_neighbors in [2, 3, 5, 10]:
    z = LocallyLinearEmbedding(
        n_components=2,
        n_neighbors=n_neighbors
    ).fit_transform(x)
    title = 'LLE with n_neighbors = {}'.format(n_neighbors)
    plots.append(draw_figure(z, y, title, show_figure=False))

gp = gridplot([[plots[0], plots[1]], [plots[2], plots[3]]])
show(gp)
export_png(gp, '../assets/figures/embedding_for_vis_lle_various_k.png')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="053f9d34-3207-4ee5-8c17-c28eddb6a641"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("053f9d34-3207-4ee5-8c17-c28eddb6a641");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("053f9d34-3207-4ee5-8c17-c28eddb6a641");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '053f9d34-3207-4ee5-8c17-c28eddb6a641' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6fa0a285-73bb-4296-ad36-1fdafe6dff82":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":
type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"40a2c738-9dc8-4822-9579-bd5a2befb746","type":"LinearAxis"},{"id":"532c8ac6-5c30-4669-80ba-b2f9cf843d45","type":"Grid"},{"id":"c63a4d5c-5614-4259-a6b2-aa5a150d2060","type":"LinearAxis"},{"id":"2522f47f-688a-4784-8772-ee84fd900aa2","type":"Grid"},{"id":"6040b3b4-ff3c-496e-937d-8a72f00db0ce","type":"BoxAnnotation"},{"id":"80fbead8-f046-4878-871e-8927666b7666","type":"GlyphRenderer"},{"id":"ef7ab19e-3583-410f-8865-3834556e7ac7","type":"GlyphRenderer"},{"id":"ac2f1d8b-2700-408b-94b7-6de5dc3fe004","type":"GlyphRenderer"}],"title":{"id":"807e53a8-0e15-4452-b94c-0805d14486ee","type":"Title"},"toolbar":{"id":"c68e8e60-e062-4599-b96f-3d708c7b8848","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"3c07e652-2fed-4861-ba4c-1f6d499f57b1","type":"DataRange1d"},"x_scale":{"id":"61140cb1-48e9-4dab-a75e-5bfca444d900","type":"LinearScale"},"y_range":{"id":"87adfe8e-a9de-4c17-89b9-343aa29be6d1","type":"DataRange1d"},"y_scale ...
# /home/lovit/anaconda2/envs/scrapper/lib/python3.6/site-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# WARNING:bokeh.io:The webdriver raised a TimeoutException while waiting for                      a 'bokeh:idle' event to signify that the layout has rendered.                      Something may have gone wrong.
# '/mnt/lovit/git/lovit.github.io/assets/figures/embedding_for_vis_lle_various_k.png'

# %%
from sklearn.manifold import Isomap

plots = []
for n_neighbors in [2, 3, 5, 10]:
    z = Isomap(
        n_components=2,
        n_neighbors=n_neighbors
    ).fit_transform(x)
    title = 'ISOMAP with n_neighbors = {}'.format(n_neighbors)
    plots.append(draw_figure(z, y, title, show_figure=False))

gp = gridplot([[plots[0], plots[1]], [plots[2], plots[3]]])
show(gp)
export_png(gp, '../assets/figures/embedding_for_vis_isomap_various_k.png')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="97f1bdb2-ec72-4dad-8ad8-074a64f996ba"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("97f1bdb2-ec72-4dad-8ad8-074a64f996ba");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("97f1bdb2-ec72-4dad-8ad8-074a64f996ba");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '97f1bdb2-ec72-4dad-8ad8-074a64f996ba' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"34abfd79-920a-48fe-998f-e3e3f93e9fca":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a9f6da8a-de6b-460c-9ef8-a211487d6b7c","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"31888d85-0607-4770-9972-a3e8d909337c","subtype":"Figure","type":"Plot"},"ticker":{"id":"06749160-b934-4870-8240-0354aa3c5384","type":"BasicTicker"}},"id":"6e8e5038-933c-465e-a9b1-8e281f23ab1d","type":"Grid"},{"attributes":{},"id":"b2858728-59a7-48cc-8fb1-afd29eded27a","type":"BasicTicker"},{"attributes":{"plot":{"id":"b5b92f08-9e4b-4cf3-9f7c-1a7c38669cc8","subtype":"Figure","type":"Plot"},"ticker":{"id":"b2d89cbb-2f0d-40e1-b533-cc43975ed8ac","type":"BasicTicker"}},"id":"9cd90680-5eeb-4dfe-9d57-c72dc6a61d0e","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"b5b92f08-9e4b-4cf3-9f7c-1a7c38669cc8","subtype":"Figure","type":"Plot"},"ticker":{"id":"ec3b9502-d944-4c2f-a33e-6b9911738dc8","type":"BasicTicker"}},"id":"df4bf6b1-b130-41d6-b7f6-f0711ba5459d","type":"Grid"},{"attributes":{"source":{"id":"70e5ecfc-a63a-461e-ae05-e149abf91eeb","type":"ColumnDataSource"}},"id":"14dcb479-add6-41b5-8a1c-4b9b6ed0e720","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"
},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","li ...
# /home/lovit/anaconda2/envs/scrapper/lib/python3.6/site-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# WARNING:bokeh.io:The webdriver raised a TimeoutException while waiting for                      a 'bokeh:idle' event to signify that the layout has rendered.                      Something may have gone wrong.
# '/mnt/lovit/git/lovit.github.io/assets/figures/embedding_for_vis_isomap_various_k.png'

# %%
from sklearn.decomposition import PCA

z = PCA(n_components=2).fit_transform(x)
title = 'PCA'
p = draw_figure(z, y, title)
export_png(p, '../assets/figures/embedding_for_vis_pca.png')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e4904284-cea3-499d-9f61-355e5b8e4529"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("e4904284-cea3-499d-9f61-355e5b8e4529");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e4904284-cea3-499d-9f61-355e5b8e4529");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e4904284-cea3-499d-9f61-355e5b8e4529' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2a87f78c-d000-4d4f-b527-01dbe4663826":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7911d0ac-0854-46dc-9a17-8c3ba811eb27","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"1d2176f2-3aea-4746-8cf7-131be9f48695","type":"ColumnDataSource"},"glyph":{"id":"65321b0a-1760-42a8-9282-f7599c84f775","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"26c0107d-d6dc-4385-b910-5a9acfa69280","type":"Circle"},"selection_glyph":null,"view":{"id":"9be5d834-3e2d-44c3-99f4-87e5db93d116","type":"CDSView"}},"id":"317a01b7-6841-48b1-a4d0-9536b4cdc55a","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ad614735-ba39-42cf-80e0-ecb1eb3575c4","type":"Circle"},{"attributes":{},"id":"69f766a9-72fe-46f5-8927-d25efd5dfeeb","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"aceb26af-6601-494f-a393-8f2e8bbb7096","type":"PanTool"},{"id":"7d4cfcb0-ea6d-4617-a805-9595ac7dfbab","type":"WheelZoomTool"},{"id":"07baf905-43a6-4068-93b0-5cdca88e280b","type":"BoxZoomTool"},{"id":"5569de5f-e1ed-448b-88c9-93d978d6ce86","type":"SaveTool"},{"id":"69f766a9-72fe-46f5-8927-d25efd5dfeeb","type":"ResetTool"},{"id":"6005d270-f646-4167-a549-1840edb6b57c","type":"HelpTool"}]},"id":"0308ddcd-43fc-4615-85da-a3d71ed3e9af","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[50]},"y":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"caa374cf-e6c7-43fa-bbac-78ae3f42cea0","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"e9cfa14e-1396-4d89-b4bf-36ec31e53b52","type":"BasicTickFormatter"},"plot":{"id":"6ffedf2c-7345-4fa6-a2be-f61aef128524","subtype":"Figure","type":"Plot"},"ticker":{"id":"5a83cf98-6f51-4057-a229-942c595b253f","type":"BasicTicker"}},"id":"a74cbde5-da1f-4647-a43e-bd44dbd46d65","type":"LinearAxis"},{"attributes":{},"id":"e9cfa14e-1396-4d89-b4bf-36ec31e53b52","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"6ffedf2c-7345-4fa6-a2be-f61aef128524","subtype":"Figure","type":"Plot"},"ticker":{"id":"5a83cf98-6f51-4057-a229-942c595b253f","type":"BasicTicker"}},"id":"9314dd58-472a-47cb-a636-1e60fb7b9118","type":"Grid"},{"attributes":{"fill_color":{"value":"darksalmon"},"line_color":{"value":"darksalmon"},"x":{"field":"x"},"y":{"field":"y"}},"id":"65321b0a-1760-42a8-9282-f7599c84f775","type":"Circle"},{"attributes":{},"id":"5a83cf98-6f51-4057-a229-942c595b253f","type":"BasicTicker"},{"attributes":{"callback":null},"id":"db009efd-9023-42a4-a7c7-0b825084c1e4","type":"DataRange1d"},{"attributes":{"data_source":{"id":"caa374cf-e6c7-43fa-bbac-78ae3f42cea0","type":"ColumnDataSource"},"glyph":{"id":"6a4d360c-7c74-4679-aeb3-b68a301a4fd4","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ad614735-ba39-42cf-80e0-ecb1eb3575c4","type":"Circle"},"selection_glyph":null,"view":{"id":"e5827f5f-a502-4fd8-b41b-cc37a67d8991","type":"CDSView"}},"id":"f18b3170-5e38-47e2-8fbb-9a4843262e96","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"2e7fa666-577b-4848-a5bf-4f1316440944","type":"BasicTickFormatter"},"plot":{"id":"6ffedf2c-7345-4fa6-a2be-f61aef128524","subtype":"Figure","type":"Plot"},"ticker":{"id":"54102a65-8cad-488e-8b75-529d412a641f","type":"BasicTicker"}},"id":"2d5679ef-ecb2-464e-a56d-d1c15dacffa3","type":"LinearAxis"},{"attributes":{"data_source":{"id":"199db227-5185-4651-aa43-754d75b7d0af","type":"ColumnDataSource"},"glyph":{"id": ...
# /home/lovit/anaconda2/envs/scrapper/lib/python3.6/site-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# WARNING:bokeh.io:The webdriver raised a TimeoutException while waiting for                      a 'bokeh:idle' event to signify that the layout has rendered.                      Something may have gone wrong.
# '/mnt/lovit/git/lovit.github.io/assets/figures/embedding_for_vis_pca.png'

# %%
from sklearn.decomposition import KernelPCA

z = KernelPCA(n_components=2).fit_transform(x)
title = 'PCA'
p = draw_figure(z, y, title)
export_png(p, '../assets/figures/embedding_for_vis_kpca.png')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="de30dca7-c041-4a7d-932c-5dffc1d236b1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("de30dca7-c041-4a7d-932c-5dffc1d236b1");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("de30dca7-c041-4a7d-932c-5dffc1d236b1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'de30dca7-c041-4a7d-932c-5dffc1d236b1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3894d811-f4a2-4e2f-a3cd-f68ef4b66a7a":{"roots":{"references":[{"attributes":{"callback":null},"id":"78c2acb5-cde9-446a-a8cf-6733b1db278d","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b2bd1e72-01e9-4d12-9645-e0b46dae01db","type":"PanTool"},{"id":"be56964f-08dd-47cb-b3b2-b9fe8c2c1984","type":"WheelZoomTool"},{"id":"f614f07e-a8cc-4386-b8e1-05afee2bae82","type":"BoxZoomTool"},{"id":"efd3a844-941c-4cef-b932-3209dc386383","type":"SaveTool"},{"id":"e773e7a6-546d-40e6-8b86-864593395929","type":"ResetTool"},{"id":"44aa8501-977f-49f8-8060-e8d18543cda4","type":"HelpTool"}]},"id":"a3a32f5e-4fb1-42ca-8ba6-ab97c1074c52","type":"Toolbar"},{"attributes":{},"id":"efd3a844-941c-4cef-b932-3209dc386383","type":"SaveTool"},{"attributes":{"overlay":{"id":"3a12440e-10c5-4114-abd7-6fc4d7e5e092","type":"BoxAnnotation"}},"id":"f614f07e-a8cc-4386-b8e1-05afee2bae82","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[50]},"y":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"196cd82b-91db-44fb-bdec-eb432b39b116","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[50]},"y":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"0464c0bf-f704-4808-8cfa-2e699cfb1646","type":"ColumnDataSource"},{"attributes":{"source":{"id":"196cd82b-91db-44fb-bdec-eb432b39b116","type":"ColumnDataSource"}},"id":"93c0045f-0a9c-45cb-91c7-8729632590c4","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"42d2e7c9-eddc-4048-b40e-792ffb861e68","type":"Circle"},{"attributes":{"data_source":{"id":"0464c0bf-f704-4808-8cfa-2e699cfb1646","type":"ColumnDataSource"},"glyph":{"id":"b01b44be-60b4-432f-bfa8-7b2d88b764a5","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"09181ae5-0ccc-4a3e-98a4-2adf36902c44","type":"Circle"},"selection_glyph":null,"view":{"id":"2e5741b1-ceb6-43c4-98ee-fd8aeba57a1f","type":"CDSView"}},"id":"c765e3d7-1469-4fb7-aa38-fae3d2ed8ebe","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"darksalmon"},"line_color":{"value":"darksalmon"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b01b44be-60b4-432f-bfa8-7b2d88b764a5","type":"Circle"},{"attributes":{"fill_color":{"value":"lightseagreen"},"line_color":{"value":"lightseagreen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6fa75001-0dbd-4a51-b3b8-13649788115e","type":"Circle"},{"attributes":{},"id":"3432ad1e-27b0-4f56-968b-f01d8299eea9","type":"BasicTickFormatter"},{"attributes":{"source":{"id":"6a5a76ff-c852-45d0-bb4c-e43710a5e3d4","type":"ColumnDataSource"}},"id":"2bc60b8e-0e80-47e6-aa0b-9e37b70ba2d6","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"91970bac-a451-41ec-9ef4-5d5aa15d1ec1","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[50]},"y":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"6a5a76ff-c852-45d0-bb4c-e43710a5e3d4","type":"ColumnDataSource"},{"attributes":{},"id":"9cc10af9-93da-4441-a3e1-9cce6a5928a6","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"09181ae5-0ccc-4a3e-98a4-2adf36902c44","type":"Circle"},{"attributes":{"plot":null,"text":"PCA"},"id":"30e84099-6784-4074-8dcf-c527b6684144","type":"Title"},{"attributes":{},"id":"eb193215-11c3-4851-9397-3039ea488875","type":"LinearScale"},{"attributes":{"source":{"id":"0464c0bf-f704 ...
# /home/lovit/anaconda2/envs/scrapper/lib/python3.6/site-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# WARNING:bokeh.io:The webdriver raised a TimeoutException while waiting for                      a 'bokeh:idle' event to signify that the layout has rendered.                      Something may have gone wrong.
# '/mnt/lovit/git/lovit.github.io/assets/figures/embedding_for_vis_kpca.png'
