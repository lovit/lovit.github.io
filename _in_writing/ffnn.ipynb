# %% [markdown]
# ## feed-forward neural network

# %%
import sys
sys.path.append('/mnt/lovit/git/synthetic_dataset/')
import soydata
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
from soydata.visualize import ipython_2d_scatter
from soydata.data import make_radial
from soydata.data import make_two_layer_radial

# %% [markdown]
# ## Easy easy

# %%
X_0, y_0 = make_radial(n_samples_per_sections=300,
    n_classes=5, n_sections_per_class=1, gap=0.1)

ipython_2d_scatter(X_0, y_0)
# Out:
# <div id="4a0ad4a0-c780-42af-a446-0398ff4fe6e4" style="height: 600px; width: 600px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4a0ad4a0-c780-42af-a446-0398ff4fe6e4", [{"type": "scatter", "x": [0.8802582362561084, 0.7321279712596314, 0.8262694626486422, 0.8081276546576134, 0.7575659262416722, 0.5664055581043023, 0.6423498461706392, 0.43616415264934894, 0.5298705596009364, 0.9095101463953562, 0.6132528747014485, 0.27464609982358, 0.33690899065543367, 0.6642462607158524, 0.4744107871461718, 0.9478273322870314, 0.46699505651779355, 0.6284214422954318, 0.618854726032382, 0.4241307109519604, 0.2786676913825367, 0.4838298915802449, 0.3334530195155517, 0.09757780571607594, 0.27935711836801697, 0.7975976229300525, 0.45368421736870096, 0.7379299539501328, 0.6585955118973598, 0.8445416159251323, 0.8022777015288293, 0.7003093036564267, 0.37
# ...

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

lr_0 = LogisticRegression()
lr_0.fit(X_0, y_0)

color = np.asarray([i for i in range(5)])
ipython_2d_scatter(lr_0.coef_, color, marker_size=10)
# Out:
# <div id="61fca074-0c87-4cad-b8a0-c6c3d67e992a" style="height: 600px; width: 600px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("61fca074-0c87-4cad-b8a0-c6c3d67e992a", [{"type": "scatter", "x": [5.0905065574854556], "y": [3.745806432231033], "text": ["point #0"], "mode": "markers", "marker": {"size": 10, "color": 0.0, "colorscale": "Jet"}, "opacity": 0.8}, {"type": "scatter", "x": [-1.8628633487480508], "y": [6.285455963787736], "text": ["point #1"], "mode": "markers", "marker": {"size": 10, "color": 0.25, "colorscale": "Jet"}, "opacity": 0.8}, {"type": "scatter", "x": [-6.446190293236883], "y": [-0.10360303657274766], "text": ["point #2"], "mode": "markers", "marker": {"size": 10, "color": 0.5, "colorscale": "Jet"}, "opacity": 0.8}, {"type": "scatter", "x": [-2.249380302160747], "y": [-6.5675706649567775], "text": ["point #3"], "
# ...

# %%
from sklearn.neural_network import MLPClassifier

mlp_00 = MLPClassifier(hidden_layer_sizes=(5,), max_iter=2000, activation='tanh')
mlp_00.fit(X_0, y_0)
# Out:
# MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(5,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=2000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
def relu(x):
    return max(0, x)

def forward_01(x):

# %%
mlp_00.intercepts_[1]
# Out:
# array([ 0.1129803 ,  0.00487306, -0.17423325,  0.49785918, -0.34331233])

# %%
color = np.asarray([i for i in range(5)])
ipython_2d_scatter(mlp_00.coefs_[0].T, color, marker_size=10)
# Out:
# <div id="bf16c53d-d619-42ce-a6bd-3114600b6eaa" style="height: 600px; width: 600px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bf16c53d-d619-42ce-a6bd-3114600b6eaa", [{"type": "scatter", "x": [0.8760504940361696], "y": [3.2083078217243894], "text": ["point #0"], "mode": "markers", "marker": {"size": 10, "color": 0.0, "colorscale": "Jet"}, "opacity": 0.8}, {"type": "scatter", "x": [2.369911609419316], "y": [1.502773184396772], "text": ["point #1"], "mode": "markers", "marker": {"size": 10, "color": 0.25, "colorscale": "Jet"}, "opacity": 0.8}, {"type": "scatter", "x": [-1.2934497082974281], "y": [2.9113179467067387], "text": ["point #2"], "mode": "markers", "marker": {"size": 10, "color": 0.5, "colorscale": "Jet"}, "opacity": 0.8}, {"type": "scatter", "x": [-3.8580855036030606], "y": [0.7141000666924695], "text": ["point #3"], "mo
# ...

# %%
mlp_00.coefs_[1].shape
# Out:
# (5, 5)
